# %%
# importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
from os import listdir
from sklearn.preprocessing import  LabelBinarizer
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array, array_to_img
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense
from sklearn.model_selection import train_test_split

# %%
# Setting path and creating empty list
dir = "/content/drive/MyDrive/DATASETS/Bird Speciees Dataset"
root_dir = listdir(dir)
image_list, label_list = [], []

# %%
# Reading and converting image to numpy array
for directory in root_dir:
  for files in listdir(f"{dir}/{directory}"):
    image_path = f"{dir}/{directory}/{files}"
    image = cv2.imread(image_path)
    image = img_to_array(image)
    image_list.append(image)
    label_list.append(directory)

# %%
# Visualize the number of classes count
label_counts = pd.DataFrame(label_list).value_counts()
label_counts
# Out:
# AMERICAN GOLDFINCH    143
# FLAMINGO              142
# EMPEROR PENGUIN       139
# DOWNY WOODPECKER      137
# CARMINE BEE-EATER     131
# BARN OWL              129
# dtype: int64

# %%
# Storing number of classes
num_classes = len(label_counts)
num_classes
# Out:
# 6

# %%
# Checking input image shape
image_list[0].shape
# Out:
# (224, 224, 3)

# %%
# Checking labels shape
label_list = np.array(label_list)
label_list.shape
# Out:
# (821,)

# %%
# Splitting dataset
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %%
# Normalize and reshape data
x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape( -1, 224,224,3)
x_test = x_test.reshape( -1, 224,224,3)

# %%
# Label binarizing
lb = LabelBinarizer()
y_train = lb.fit_transform(y_train)
y_test = lb.fit_transform(y_test)
print(lb.classes_)
# Out:
# ['AMERICAN GOLDFINCH' 'BARN OWL' 'CARMINE BEE-EATER' 'DOWNY WOODPECKER'
#  'EMPEROR PENGUIN' 'FLAMINGO']

# %%
# Splitting the training data set into training and validation data sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2)

# %%
# Building model architecture
model = Sequential([
    Conv2D(16, (3, 3), padding="same", input_shape=(224, 224, 3), activation="relu"),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(32, (3, 3), padding="same", activation="relu"),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(64, (3, 3), padding="same", activation="relu"),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(128, (3, 3), padding="same", activation="relu"),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(256, (3, 3), padding="same", activation="relu"),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(256, activation="relu"),
    Dropout(0.5),  # Adding dropout
    Dense(num_classes, activation="softmax")
])

# Display model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 112, 112, 16)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 32)      4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 56, 56, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 28, 28, 64)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 128)       73856
#
#  max_pooling2d_3 (MaxPoolin  (None, 14, 14, 128)       0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 256)       295168
#
#  max_pooling2d_4 (MaxPoolin  (None, 7, 7, 256)         0
#  g2D)
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 256)               3211520
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 6)                 1542
#
# =================================================================
# Total params: 3605670 (13.75 MB)
# Trainable params: 3605670 (13.75 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compiling model
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0005),metrics=['accuracy'])

# %%
# Training the model
epochs = 50
batch_size = 128
history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs, validation_data = (x_val, y_val))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 1s 197ms/step - loss: 0.1331 - accuracy: 0.9447 - val_loss: 0.3261 - val_accuracy: 0.8561
# Epoch 2/50
# 5/5 [==============================] - 1s 123ms/step - loss: 0.1430 - accuracy: 0.9466 - val_loss: 0.2605 - val_accuracy: 0.9091
# Epoch 3/50
# 5/5 [==============================] - 1s 135ms/step - loss: 0.1547 - accuracy: 0.9466 - val_loss: 0.2777 - val_accuracy: 0.9167
# Epoch 4/50
# 5/5 [==============================] - 1s 146ms/step - loss: 0.1106 - accuracy: 0.9599 - val_loss: 0.3842 - val_accuracy: 0.8788
# Epoch 5/50
# 5/5 [==============================] - 1s 156ms/step - loss: 0.1224 - accuracy: 0.9561 - val_loss: 0.3350 - val_accuracy: 0.8864
# Epoch 6/50
# 5/5 [==============================] - 1s 144ms/step - loss: 0.1019 - accuracy: 0.9599 - val_loss: 0.2778 - val_accuracy: 0.9015
# Epoch 7/50
# 5/5 [==============================] - 1s 139ms/step - loss: 0.0712 - accuracy: 0.9752 - val_loss: 0.2596 - val_accuracy: 0.9167
# Epoch 8/50
# 5/5 [==============================] - 1s 157ms/step - loss: 0.0406 - accuracy: 0.9905 - val_loss: 0.3026 - val_accuracy: 0.9015
# Epoch 9/50
# 5/5 [==============================] - 1s 123ms/step - loss: 0.0434 - accuracy: 0.9847 - val_loss: 0.3209 - val_accuracy: 0.8939
# Epoch 10/50
# 5/5 [==============================] - 1s 124ms/step - loss: 0.0404 - accuracy: 0.9847 - val_loss: 0.2887 - val_accuracy: 0.9091
# Epoch 11/50
# 5/5 [==============================] - 1s 123ms/step - loss: 0.0273 - accuracy: 0.9943 - val_loss: 0.2782 - val_accuracy: 0.9394
# Epoch 12/50
# 5/5 [==============================] - 1s 124ms/step - loss: 0.0216 - accuracy: 0.9962 - val_loss: 0.2981 - val_accuracy: 0.9015
# Epoch 13/50
# 5/5 [==============================] - 1s 133ms/step - loss: 0.0206 - accuracy: 0.9943 - val_loss: 0.2904 - val_accuracy: 0.9242
# Epoch 14/50
# 5/5 [==============================] - 1s 122ms/step - loss: 0.0144 - accuracy: 0.9962 - val_loss: 0.2863 - val_accuracy: 0.9015
# Epoch 15/50
# 5/5 [==============================] - 1s 134ms/step - loss: 0.0144 - accuracy: 0.9962 - val_loss: 0.2916 - val_accuracy: 0.9167
# Epoch 16/50
# 5/5 [==============================] - 1s 122ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.3060 - val_accuracy: 0.9167
# Epoch 17/50
# 5/5 [==============================] - 1s 125ms/step - loss: 0.0226 - accuracy: 0.9924 - val_loss: 0.3131 - val_accuracy: 0.8939
# Epoch 18/50
# 5/5 [==============================] - 1s 141ms/step - loss: 0.0336 - accuracy: 0.9866 - val_loss: 0.3597 - val_accuracy: 0.9091
# Epoch 19/50
# 5/5 [==============================] - 1s 138ms/step - loss: 0.0227 - accuracy: 0.9924 - val_loss: 0.3838 - val_accuracy: 0.8788
# Epoch 20/50
# 5/5 [==============================] - 1s 134ms/step - loss: 0.0282 - accuracy: 0.9866 - val_loss: 0.3472 - val_accuracy: 0.9015
# Epoch 21/50
# 5/5 [==============================] - 1s 128ms/step - loss: 0.0245 - accuracy: 0.9924 - val_loss: 0.3341 - val_accuracy: 0.9015
# Epoch 22/50
# 5/5 [==============================] - 1s 134ms/step - loss: 0.0290 - accuracy: 0.9905 - val_loss: 0.3294 - val_accuracy: 0.9091
# Epoch 23/50
# 5/5 [==============================] - 1s 135ms/step - loss: 0.0246 - accuracy: 0.9924 - val_loss: 0.3721 - val_accuracy: 0.8939
# Epoch 24/50
# 5/5 [==============================] - 1s 138ms/step - loss: 0.0172 - accuracy: 0.9943 - val_loss: 0.4191 - val_accuracy: 0.8864
# Epoch 25/50
# 5/5 [==============================] - 1s 154ms/step - loss: 0.0130 - accuracy: 0.9981 - val_loss: 0.3942 - val_accuracy: 0.8864
# Epoch 26/50
# 5/5 [==============================] - 1s 153ms/step - loss: 0.0174 - accuracy: 0.9943 - val_loss: 0.3708 - val_accuracy: 0.8939
# Epoch 27/50
# 5/5 [==============================] - 1s 154ms/step - loss: 0.0141 - accuracy: 0.9943 - val_loss: 0.3798 - val_accuracy: 0.9167
# Epoch 28/50
# 5/5 [==============================] - 1s 154ms/step - loss: 0.0111 - accuracy: 0.9962 - val_loss: 0.3605 - val_accuracy: 0.9091
# Epoch 29/50
# 5/5 [==============================] - 1s 124ms/step - loss: 0.0149 - accuracy: 0.9962 - val_loss: 0.3636 - val_accuracy: 0.9015
# Epoch 30/50
# 5/5 [==============================] - 1s 135ms/step - loss: 0.0083 - accuracy: 0.9981 - val_loss: 0.3594 - val_accuracy: 0.9091
# Epoch 31/50
# 5/5 [==============================] - 1s 126ms/step - loss: 0.0117 - accuracy: 0.9962 - val_loss: 0.3705 - val_accuracy: 0.8939
# Epoch 32/50
# 5/5 [==============================] - 1s 124ms/step - loss: 0.0118 - accuracy: 0.9924 - val_loss: 0.3535 - val_accuracy: 0.9091
# Epoch 33/50
# 5/5 [==============================] - 1s 127ms/step - loss: 0.0052 - accuracy: 0.9981 - val_loss: 0.3544 - val_accuracy: 0.9091
# Epoch 34/50
# 5/5 [==============================] - 1s 134ms/step - loss: 0.0118 - accuracy: 0.9981 - val_loss: 0.4070 - val_accuracy: 0.9091
# Epoch 35/50
# 5/5 [==============================] - 1s 136ms/step - loss: 0.0120 - accuracy: 0.9943 - val_loss: 0.3400 - val_accuracy: 0.9167
# Epoch 36/50
# 5/5 [==============================] - 1s 123ms/step - loss: 0.0144 - accuracy: 0.9962 - val_loss: 0.3254 - val_accuracy: 0.9242
# Epoch 37/50
# 5/5 [==============================] - 1s 134ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.3672 - val_accuracy: 0.8939
# Epoch 38/50
# 5/5 [==============================] - 1s 134ms/step - loss: 0.0084 - accuracy: 0.9981 - val_loss: 0.3563 - val_accuracy: 0.9015
# Epoch 39/50
# 5/5 [==============================] - 1s 134ms/step - loss: 0.0064 - accuracy: 0.9981 - val_loss: 0.3522 - val_accuracy: 0.8864
# Epoch 40/50
# 5/5 [==============================] - 1s 135ms/step - loss: 0.0065 - accuracy: 0.9981 - val_loss: 0.3672 - val_accuracy: 0.9015
# Epoch 41/50
# 5/5 [==============================] - 1s 137ms/step - loss: 0.0105 - accuracy: 0.9981 - val_loss: 0.3839 - val_accuracy: 0.9015
# Epoch 42/50
# 5/5 [==============================] - 1s 125ms/step - loss: 0.0103 - accuracy: 0.9981 - val_loss: 0.3385 - val_accuracy: 0.8712
# Epoch 43/50
# 5/5 [==============================] - 1s 137ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.3419 - val_accuracy: 0.8939
# Epoch 44/50
# 5/5 [==============================] - 1s 142ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.3917 - val_accuracy: 0.9015
# Epoch 45/50
# 5/5 [==============================] - 1s 154ms/step - loss: 0.0044 - accuracy: 0.9981 - val_loss: 0.4218 - val_accuracy: 0.9015
# Epoch 46/50
# 5/5 [==============================] - 1s 155ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.4431 - val_accuracy: 0.8939
# Epoch 47/50
# 5/5 [==============================] - 1s 147ms/step - loss: 0.0074 - accuracy: 0.9962 - val_loss: 0.4298 - val_accuracy: 0.8864
# Epoch 48/50
# 5/5 [==============================] - 1s 136ms/step - loss: 0.0186 - accuracy: 0.9981 - val_loss: 0.6959 - val_accuracy: 0.8258
# Epoch 49/50
# 5/5 [==============================] - 1s 124ms/step - loss: 0.1338 - accuracy: 0.9561 - val_loss: 0.4705 - val_accuracy: 0.8636
# Epoch 50/50
# 5/5 [==============================] - 1s 130ms/step - loss: 0.1633 - accuracy: 0.9466 - val_loss: 0.3906 - val_accuracy: 0.8712

# %%
# Saving model
model.save("/content/drive/My Drive/bird_species.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
#Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %%
#Plot the loss history
plt.figure(figsize=(12, 5))
plt.plot(history.history['loss'], color='r')
plt.plot(history.history['val_loss'], color='b')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %%
# Calculating test accuracy
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# 6/6 [==============================] - 1s 160ms/step - loss: 0.3755 - accuracy: 0.9273
# Test Accuracy: 92.72727370262146

# %%
# Storing predictions
y_pred = model.predict(x_test)
# Out:
# 6/6 [==============================] - 0s 14ms/step

# %%
# Plotting image to compare
img = array_to_img(x_test[10])
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
# Finding max value from predition list and comaparing original value vs predicted
labels = lb.classes_
print(labels)
print("Originally : ",labels[np.argmax(y_test[10])])
print("Predicted : ",labels[np.argmax(y_pred[10])])
# Out:
# ['AMERICAN GOLDFINCH' 'BARN OWL' 'CARMINE BEE-EATER' 'DOWNY WOODPECKER'
#  'EMPEROR PENGUIN' 'FLAMINGO']
# Originally :  EMPEROR PENGUIN
# Predicted :  EMPEROR PENGUIN
